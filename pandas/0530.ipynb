# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinoryong/hanaro01/blob/main/0530.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 웹에서 가져오기(계속)

# %% [markdown]
# ## API 이용한 데이터 수집

# %%
# 구글 맵스 설치
# pip install googlemaps
# !pip install googlemaps
# 메뉴 - 런타임 - 런타임 다시 시작 선택

# %%
# 라이브러리 불러오기
import googlemaps
import pandas as pd

# %%
api_key = '' # 본인이 발급받은 키를 입력해서 사용할 것!

# %%
# 구글 맵스 객체 생성
maps = googlemaps.Client(key = api_key)

# %%
maps.geocode("해운대해수욕장")[0].get('geometry')
# Out:
# {'location': {'lat': 35.1586975, 'lng': 129.1603842},
#  'location_type': 'APPROXIMATE',
#  'viewport': {'northeast': {'lat': 35.1600464802915, 'lng': 129.1617331802915},
#   'southwest': {'lat': 35.1573485197085, 'lng': 129.1590352197085}}}

# %%
# 장소 리스트를 이용하여 지오코딩하는 프로그램
places = ['해운대해수욕장','광안리해수욕장','송정해수욕장','정동진역']
lat = []
lng = []
i = 0
for place in places:
  i += 1
  print(i, place)
  geo_coding = maps.geocode(place)[0].get('geometry')
  lat.append(geo_coding['location']['lat'])
  lng.append(geo_coding['location']['lng'])
df = pd.DataFrame({'위도': lat,
                   '경도': lng})
print(df)
# Out:
# 1 해운대해수욕장
# 2 광안리해수욕장
# 3 송정해수욕장
# 4 정동진역
#           위도          경도
# 0  35.158698  129.160384
# 1  35.153170  129.118666
# 2  35.178613  129.199713
# 3  37.691884  129.021387

# %%
# 주소를 이용하여 지오코딩
maps.geocode("서울특별시 성동구 아차산로 111 2층")

# %%
maps.geocode("서울특별시 성동구 아차산로 111 2층")[0].get('geometry')
# Out:
# {'location': {'lat': 37.5448181, 'lng': 127.0565111},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 37.5461670802915, 'lng': 127.0578600802915},
#   'southwest': {'lat': 37.5434691197085, 'lng': 127.0551621197085}}}

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# ## 데이터프레임 구조

# %% [markdown]
# ### 데이터 미리 보기

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
# csv 파일 불러오기 + 열 이름이 없음(header = None)
df = pd.read_csv('/content/drive/MyDrive/hana1/data/auto-mpg.csv', header = None)

# %%
# 열 이름 지정
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 
              'acceleration', 'model_year', 'origin', 'car_name']

# %%
# 데이터 미리 보기 = 살펴 보기
# head, tail
# 앞 부분 보기
df.head() # 기본값이 5개의 행

# %%
# 10개의 행
df.head(10)

# %%
# 3개의 행
df.head(3)

# %%
# 뒷 부분 보기
df.tail() # 기본값이 5개의 행

# %%
# 10개의 행
df.tail(10)

# %%
# 3개의 행
df.tail(3)

# %% [markdown]
# ### 데이터 요약 정보 확인

# %%
# 데이터의 크기 확인 = 2개의 값이 튜플 형태로 출력 = (행의 개수, 열의 개수)
df.shape

# %%
# 데이터의 기본 정보
df.info()

# %%
# 데이터의 자료형 확인
# 데이터의 모든 열의 자료형
df.dtypes

# %%
# 특정 열의 자료형
df.mpg.dtypes

# %%
df['mpg'].dtypes

# %%
df[['mpg', 'weight']].dtypes

# %%
# 기술통계 정보 요약
df.describe() # 요약할 수 있는 숫자형 열이 7개

# %%
df.describe(include = 'all')

# %% [markdown]
# ### 데이터 개수 확인

# %%
# 데이터의 모든 열의 개수 확인
print(df.count())
print(type(df.count()))

# %%
# 특정 열의 개수 확인
print(df.mpg.count())
print(type(df.mpg.count()))

# %%
print(df['mpg'].count())
print(type(df['mpg'].count()))

# %%
print(df[['mpg', 'weight']].count())
print(type(df[['mpg', 'weight']].count()))

# %%
# 고유값 개수 = 빈도표 = 빈도가 높은 순으로 정렬
print(df.origin.value_counts())
print(type(df.origin.value_counts()))

# %%
print(df['origin'].value_counts())
print(type(df['origin'].value_counts()))

# %%
print(df[['origin', 'car_name']].value_counts())
print(type(df[['origin', 'car_name']].value_counts()))

# %% [markdown]
# ## 통계함수

# %%
# 평균
# 데이터 모든 열
print(df.mean())
print(type(df.mean()))
# 특정 열
print(df.mpg.mean())
print(type(df.mpg.mean()))
print(df['mpg'].mean())
print(type(df['mpg'].mean()))

# %%
print(df[['mpg', 'weight']].mean())
print(type(df[['mpg', 'weight']].mean()))

# %%
# 중앙값
# 데이터 모든 열
print(df.median())
# 특정 열
print(df.mpg.median())
print(df['mpg'].median())
print(df[['mpg', 'weight']].median())

# %%
# 최대값
# 데이터 모든 열
print(df.max())
# 특정 열
print(df.mpg.max())
print(df['mpg'].max())
print(df[['mpg', 'weight']].max())

# %%
# 최소값
# 데이터 모든 열
print(df.min())
# 특정 열
print(df.mpg.min())
print(df['mpg'].min())
print(df[['mpg', 'weight']].min())

# %%
# 표준편차
# 데이터 모든 열
print(df.std())
# 특정 열
print(df.mpg.std())
print(df['mpg'].std())
print(df[['mpg', 'weight']].std())

# %%
# 표준편차의 제곱 = 분산
# 표준편차 = 제곱근(분산)
print(df.mpg.std()**2)
print(df.mpg.var())

# %%
# 분산
# 데이터 모든 열
print(df.var())
# 특정 열
print(df.mpg.var())
print(df['mpg'].var())
print(df[['mpg', 'weight']].var())

# %%
# 상관계수
# 상관행렬
print(df.corr())
print(df[['mpg', 'weight']].corr())

# %% [markdown]
# ## 판다스 내장 그래프 도구

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
# 파일 경로, 파일 이름, 파일 확장자
# engine = None 기본값
df = pd.read_excel('/content/drive/MyDrive/hana1/data/남북한발전전력량.xlsx', 
                   engine = 'openpyxl')
df.head(10)

# %%
# 남한과 북한 합계, 1990~2016
df_new = df.iloc[[0, 5], 2:]
df_new.head()

# %%
df_new.index = ["South", "North"]
df_new.head()

# %% [markdown]
# ### 선 그래프

# %%
# 기본값 kind = 'line'
df_new.plot()

# %%
df_new_t = df_new.T
df_new_t.head()

# %%
df_new_t.plot()
# = df_new_t.plot(kind = 'line')

# %% [markdown]
# ### 막대 그래프

# %%
# 수직 막대 그래프
df_new.plot(kind = 'bar')

# %%
df_new_t.plot(kind = 'bar')

# %%
# 수평 막대 그래프
df_new.plot(kind = 'barh')
df_new_t.plot(kind = 'barh')

# %% [markdown]
# ### 히스토그램

# %%
df_new_t = df_new_t.astype(int)

# %%
df_new_t.plot(kind = 'hist')

# %% [markdown]
# ### 산점도

# %%
# csv 파일 불러오기 + 열 이름이 없음(header = None)
df = pd.read_csv('/content/drive/MyDrive/hana1/data/auto-mpg.csv', header = None)
# 열 이름 지정
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 
              'acceleration', 'model_year', 'origin', 'car_name']
df.head()

# %%
# 차중과 연비의 산점도
df.plot(kind = 'scatter', x = 'mpg', y = 'weight')

# %% [markdown]
# ### 상자수염그림

# %%
df[['mpg','acceleration']].plot(kind = 'box')

# %% [markdown]
# # 시각화 도구

# %%
# 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 메뉴 - 런타임 - 런타임 다시 시작

# %% [markdown]
# ## matplotlib

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 데이터 불러오기
df = pd.read_excel('/content/drive/MyDrive/hana1/data/시도별 전출입 인구수.xlsx',
                   engine = 'openpyxl')
df.head()

# %%
# NaN 값 채우기
df = df.fillna(method = 'ffill')

# %%
# 서울시(전출지)에서 다른 지역(전입지)으로 이동한 인구 데이터
# 불 인덱스(True)를 데이터 추출
b_ind = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')
df_seoul = df[b_ind]
df_seoul.head()

# %%
# 전출지별 열 삭제
df_seoul = df_seoul.drop('전출지별', axis = 1)
df_seoul.head()

# %%
# 열 이름 변경
df_seoul = df_seoul.rename({'전입지별':'전입지'}, axis = 1)
df_seoul.head()

# %%
# 행 인덱스 변경
df_seoul = df_seoul.set_index('전입지')
df_seoul.head()

# %%
df_ggd = df_seoul.loc['경기도']

# %% [markdown]
# ### 선 그래프

# %%
# 선 그래프
plt.plot(df_ggd.index, df_ggd.values)

# %%
# 시리즈 데이터를 넣고 시각화해도 결과는 동일함
plt.plot(df_ggd)

# %% [markdown]
# #### 차트 제목, 축 제목 추가

# %%
# 차트 제목, 축 제목 추가
# 한글 폰트 지정
plt.rc("font", family = "NanumGothic")
# 선 그래프
plt.plot(df_ggd.index, df_ggd.values)
# 차트 제목 추가
plt.title("서울시에서 경기도로 이동하는 인구")
# 축 제목 추가
plt.xlabel("기간(연도)")
plt.ylabel("이동 인구 수")
plt.show()

# %% [markdown]
# #### 그래프 꾸미기

# %%
# 그래프 꾸미기
# 그림 사이즈 지정(가로, 세로)
plt.figure(figsize = (13, 5))
# x 축 눈금 라벨 회전
plt.xticks(rotation = 'vertical')
# 선 그래프
plt.plot(df_ggd.index, df_ggd.values)
# 차트 제목 추가
plt.title("서울시에서 경기도로 이동하는 인구")
# 축 제목 추가
plt.xlabel("기간(연도)")
plt.ylabel("이동 인구 수")
# 범례 추가
plt.legend(labels = ["서울시 => 경기도"], loc = 'best')
plt.show()

# %% [markdown]
# #### 스타일 서식

# %%
# 스타일 서식 확인
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# 스타일 서식
plt.style.use('ggplot')
# 그림 사이즈 지정(가로, 세로)
plt.figure(figsize = (13, 5))
# x 축 눈금 라벨 회전
plt.xticks(rotation = 'vertical')
# 선 그래프
plt.plot(df_ggd.index, df_ggd.values)
# 차트 제목 추가
plt.title("서울시에서 경기도로 이동하는 인구")
# 축 제목 추가
plt.xlabel("기간(연도)")
plt.ylabel("이동 인구 수")
# 범례 추가
plt.legend(labels = ["서울시 => 경기도"], loc = 'best')
plt.show()

# %% [markdown]
# #### 주석 추가

# %%
# 스타일 서식
plt.style.use('ggplot')
# 그림 사이즈 지정(가로, 세로)
plt.figure(figsize = (13, 5))
# x 축 눈금 라벨 회전
plt.xticks(rotation = 'vertical')
# 선 그래프
plt.plot(df_ggd.index, df_ggd.values)
# 차트 제목 추가
plt.title("서울시에서 경기도로 이동하는 인구")
# 축 제목 추가
plt.xlabel("기간(연도)")
plt.ylabel("이동 인구 수")
# 범례 추가
plt.legend(labels = ["서울시 => 경기도"], loc = 'best', fontsize = 15)
# y 축 범위 조정
plt.ylim(50000, 800000)
# 주석 추가
# 화살표
plt.annotate("", xy = (23, 620000), # 화살표 머리
             xytext = (3, 250000), # 화살표 꼬리
             xycoords = 'data', # 좌표계
             arrowprops = dict(arrowstyle = '->', color = 'red', lw = 10))
plt.annotate("", xy = (45, 400000), # 화살표 머리
             xytext = (29, 620000), # 화살표 꼬리
             xycoords = 'data', # 좌표계
             arrowprops = dict(arrowstyle = '->', color = 'blue', lw = 10))
# 텍스트
plt.annotate("인구 이동 증가",
             xy = (12, 400000), # 텍스트 시작 위치
             rotation = 25, # 회전
             va = 'baseline', # 위아래 정렬
             ha = 'center', # 좌우 정렬
             fontsize = 15)
plt.annotate("인구 이동 감소",
             xy = (37, 500000), # 텍스트 시작 위치
             rotation = -18, # 회전
             va = 'baseline', # 위아래 정렬
             ha = 'center', # 좌우 정렬
             fontsize = 15)
plt.show()

# %% [markdown]
# #### 화면 분할

# %%
# 화면 분할
df_4 = df_seoul.loc[['충청남도','경상북도','강원도','전라남도']]
df_4.head()
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %%
# 1970 ~ 2018 숫자 리스트
list(range(1970,2018))

# %%
# 연도 리스트 생성
# 1970 ~ 2018 문자열 리스트
col_years = list(map(str, range(1970,2018)))
col_years

# %%
# 한글 폰트 지정
plt.rc("font", family = "NanumGothic")
# 스타일 서식
plt.style.use('ggplot')
# 그래프 객체 만들기
fig = plt.figure(figsize = (20, 10))
ax1 = fig.add_subplot(2, 2, 1) # 행의 개수, 열의 개수, 위치
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
# axe 객체에 그래프 추가
ax1.plot(col_years, df_4.loc['충청남도', :],  marker = 'o', markerfacecolor = 'green',
         markersize = 5, color = 'green', label = "서울 => 충남")
ax2.plot(col_years, df_4.loc['경상북도', :],  marker = 'o', markerfacecolor = 'red',
         markersize = 5, color = 'red', label = "서울 => 경북")
ax3.plot(col_years, df_4.loc['강원도', :],  marker = 'o', markerfacecolor = 'yellow',
         markersize = 5, color = 'yellow', label = "서울 => 강원")
ax4.plot(col_years, df_4.loc['전라남도', :],  marker = 'o', markerfacecolor = 'blue',
         markersize = 5, color = 'blue', label = "서울 => 전남")
# 범례 추가
ax1.legend(loc = 'best')
ax2.legend(loc = 'best')
ax3.legend(loc = 'best')
ax4.legend(loc = 'best')
# x 축 눈금 라벨 회전
ax1.set_xticklabels(col_years, rotation = 90)
ax2.set_xticklabels(col_years, rotation = 90)
ax3.set_xticklabels(col_years, rotation = 90)
ax4.set_xticklabels(col_years, rotation = 90)
# y 축 범위 조정
ax1.set_ylim(0, 60000)
ax2.set_ylim(0, 60000)
ax3.set_ylim(0, 60000)
ax4.set_ylim(0, 60000)
plt.show()
# Out:
# <ipython-input-19-30841f175419>:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_years, rotation = 90)
# <ipython-input-19-30841f175419>:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_years, rotation = 90)
# <ipython-input-19-30841f175419>:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(col_years, rotation = 90)
# <ipython-input-19-30841f175419>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(col_years, rotation = 90)
